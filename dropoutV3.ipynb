# %%
import pandas as pd
data=pd.read_csv('student-data.csv')

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher  \
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 3       GP   F   15       U     GT3       T     4     2   health  services
# 4       GP   F   16       U     GT3       T     3     3    other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 376     MS   F   20       U     GT3       T     4     2   health     other
# 377     MS   F   18       R     LE3       T     4     4  teacher  services
# 378     MS   F   18       U     GT3       T     3     3    other     other
# 379     MS   F   17       R     GT3       T     3     1  at_home     other
# 380     MS   M   18       U     GT3       T     4     4  teacher   teacher
#
#      ... famrel freetime  goout  Dalc  Walc health absences passed
# 0    ...      4        3      4     1     1      3        6     no  \
# 1    ...      5        3      3     1     1      3        4     no
# 2    ...      4        3      2     2     3      3       10    yes
# 3    ...      3        2      2     1     1      5        2    yes
# 4    ...      4        3      2     1     2      5        4    yes
# ..   ...    ...      ...    ...   ...   ...    ...      ...    ...
# 376  ...      5        4      3     1     1      3        4    yes
# 377  ...      5        4      3     3     4      2        4    yes
# 378  ...      4        1      3     1     2      1        0    yes
# 379  ...      4        5      4     2     3      1       17    yes
# 380  ...      3        2      4     1     4      2        4    yes
#
#     absences_cat failures_cat
# 0            low          low
# 1            low          low
# 2           high         high
# 3            low          low
# 4            low          low
# ..           ...          ...
# 376          low         high
# 377          low          low
# 378          low          low
# 379         high          low
# 380          low          low
#
# [381 rows x 33 columns]

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
from pgmpy.models import BayesianModel
bn = gum.BayesNet()

# %%
# Adding variables 
sex=bn.add(gum.LabelizedVariable('sex','sex', ['M','F']))
passed=bn.add(gum.LabelizedVariable('passed','passed', ['yes', 'no']))
famsize=bn.add(gum.LabelizedVariable('famsize','famsize', ['LE3', 'GT3']))
schoolsup=bn.add(gum.LabelizedVariable('schoolsup','schoolsup', ['yes', 'no']))
famsup=bn.add(gum.LabelizedVariable('famsup','famsup', ['yes', 'no']))
internet=bn.add(gum.LabelizedVariable('internet','internet', ['yes', 'no']))
absences_cat=bn.add(gum.LabelizedVariable('absences_cat','absences_cat', ['high', 'low']))
failures_cat=bn.add(gum.LabelizedVariable('failures_cat','failures_cat', ['high', 'low']))

# %%
# Addding arcs between the nodes
# arcs = [(sex, passed),(famsize, passed),(schoolsup, passed),(famsup, passed)]
# for arc in arcs:
#     bn.addArc(*arc)

# %%
bn
# Out:
# (pyAgrum.BayesNet<double>@000001FBABC795D0) BN{nodes: 8, arcs: 0, domainSize: 256, dim: 8, mem: 128o}

# %%
learner = gum.BNLearner(data, bn)
bn2 = learner.learnBN()
# bn2.eraseArc(absences_cat, sex)
bn2
# Out:
# (pyAgrum.BayesNet<double>@000001FBABC77910) BN{nodes: 8, arcs: 4, domainSize: 256, dim: 12, mem: 192o}

# %%
print(bn2.cpt(famsize))
# Out:
#   famsize          |
# LE3      |GT3      |
# ---------|---------|
#  0.2866  | 0.7134  |

# %%
learner
# Out:
# (pyAgrum.BNLearner<double>@000001FBABE72250) Filename       : C:\Users\ADEEBG~1\AppData\Local\Temp\tmpt6vqfqtr.csv
# Size           : (381,8)
# Variables      : sex[2], passed[2], famsize[2], schoolsup[2], famsup[2], internet[2], absences_cat[2], failures_cat[2]
# Induced types  : False
# Missing values : False
# Algorithm      : Greedy Hill Climbing
# Score          : BDeu
# Correction     : MDL  (Not used for score-based algorithms)
# Prior          : -
